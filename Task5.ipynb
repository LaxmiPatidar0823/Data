# %% [markdown]
# Task 5- Remove Duplication

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Rohit\Desktop\text jupyter\lp.csv")

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head(10)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa
# 5            5.4           3.9            1.7           0.4  Iris-setosa
# 6            4.6           3.4            1.4           0.3  Iris-setosa
# 7            5.0           3.6            1.4           0.2  Iris-setosa
# 8            4.4           2.9            1.4           0.2  Iris-setosa
# 9            4.9           3.1            1.5           0.1  Iris-setosa

# %% [markdown]
# Identify And Remove Duplicate Values

# %%
#identify how many rows are duplicate
df.duplicated().sum()
# Out:
# 4

# %%
#remove duplicate rows
df.drop_duplicates()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [146 rows x 5 columns]

# %%
df['SepalLengthCm'].duplicated().sum()
# Out:
# 115

# %%
#first five rows which are duplicate
df[df['SepalLengthCm'].duplicated()].head(5)
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 6             4.6           3.4            1.4           0.3  Iris-setosa
# 7             5.0           3.6            1.4           0.2  Iris-setosa
# 9             4.9           3.1            1.5           0.1  Iris-setosa
# 10            5.4           3.7            1.5           0.2  Iris-setosa
# 12            4.8           3.0            1.4           0.1  Iris-setosa

# %%
df[df['SepalLengthCm'].duplicated(keep='last')].head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df['SepalLengthCm'].shape
# Out:
# (150,)

# %%
df['SepalLengthCm'].drop_duplicates().shape
# Out:
# (35,)

# %%
df.drop_duplicates(subset=['SepalLengthCm'])
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0              5.1           3.5            1.4           0.2      Iris-setosa
# 1              4.9           3.0            1.4           0.2      Iris-setosa
# 2              4.7           3.2            1.3           0.2      Iris-setosa
# 3              4.6           3.1            1.5           0.2      Iris-setosa
# 4              5.0           3.6            1.4           0.2      Iris-setosa
# 5              5.4           3.9            1.7           0.4      Iris-setosa
# 8              4.4           2.9            1.4           0.2      Iris-setosa
# 11             4.8           3.4            1.6           0.2      Iris-setosa
# 13             4.3           3.0            1.1           0.1      Iris-setosa
# 14             5.8           4.0            1.2           0.2      Iris-setosa
# 15             5.7           4.4            1.5           0.4      Iris-setosa
# ...

# %%
df['PetalWidthCm'].shape
# Out:
# (150,)

# %%
df['PetalWidthCm'].drop_duplicates().shape
# Out:
# (22,)

# %%
df.drop_duplicates(subset=['PetalWidthCm'])
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0              5.1           3.5            1.4           0.2      Iris-setosa
# 5              5.4           3.9            1.7           0.4      Iris-setosa
# 6              4.6           3.4            1.4           0.3      Iris-setosa
# 9              4.9           3.1            1.5           0.1      Iris-setosa
# 23             5.1           3.3            1.7           0.5      Iris-setosa
# 43             5.0           3.5            1.6           0.6      Iris-setosa
# 50             7.0           3.2            4.7           1.4  Iris-versicolor
# 51             6.4           3.2            4.5           1.5  Iris-versicolor
# 53             5.5           2.3            4.0           1.3  Iris-versicolor
# 56             6.3           3.3            4.7           1.6  Iris-versicolor
# 57             4.9           2.4            3.3           1.0  Iris-versicolor
# ...

# %%
df['Species'].shape
# Out:
# (150,)

# %%
df['Species'].drop_duplicates().shape
# Out:
# (3,)

# %%
df.drop_duplicates(subset=['Species'])
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0              5.1           3.5            1.4           0.2      Iris-setosa
# 50             7.0           3.2            4.7           1.4  Iris-versicolor
# 100            6.3           3.3            6.0           2.5   Iris-virginica

# %%
df.drop_duplicates(subset=['PetalWidthCm','Species'])
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0              5.1           3.5            1.4           0.2      Iris-setosa
# 5              5.4           3.9            1.7           0.4      Iris-setosa
# 6              4.6           3.4            1.4           0.3      Iris-setosa
# 9              4.9           3.1            1.5           0.1      Iris-setosa
# 23             5.1           3.3            1.7           0.5      Iris-setosa
# 43             5.0           3.5            1.6           0.6      Iris-setosa
# 50             7.0           3.2            4.7           1.4  Iris-versicolor
# 51             6.4           3.2            4.5           1.5  Iris-versicolor
# 53             5.5           2.3            4.0           1.3  Iris-versicolor
# 56             6.3           3.3            4.7           1.6  Iris-versicolor
# 57             4.9           2.4            3.3           1.0  Iris-versicolor
# ...
