# %% [markdown]
# Task 4- Pivot Table

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r"C:\Users\Rohit\Desktop\text jupyter\business_employee_data.csv")

# %%
data
# Out:
#      quarter      SER_REF industry_code                        industry_name  \
# 0    2020.09  BDCQ.SEA1AA             A    Agriculture, Forestry and Fishing
# 1    2020.09  BDCQ.SEA1BA             B                               Mining
# 2    2020.09  BDCQ.SEA1CA             C                        Manufacturing
# 3    2020.09  BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4    2020.09  BDCQ.SEA1EA             E                         Construction
# ..       ...          ...           ...                                  ...
# 195  2022.12  BDCQ.SEA1PA             P               Education and Training
# 196  2022.12  BDCQ.SEA1QA             Q    Health Care and Social Assistance
# 197  2022.12  BDCQ.SEA1RA             R         Arts and Recreation Services
# 198  2022.12  BDCQ.SEA1SA             S                       Other Services
# 199  2022.12  BDCQ.SEA1ZA             Z                       Total Industry
#
# ...

# %%
data.head(n=5)
# Out:
#    quarter      SER_REF industry_code                        industry_name  \
# 0  2020.09  BDCQ.SEA1AA             A    Agriculture, Forestry and Fishing
# 1  2020.09  BDCQ.SEA1BA             B                               Mining
# 2  2020.09  BDCQ.SEA1CA             C                        Manufacturing
# 3  2020.09  BDCQ.SEA1DA             D  Electricity, Gas, Water and Waste S
# 4  2020.09  BDCQ.SEA1EA             E                         Construction
#
#    filled jobs  filled jobs revised  filled jobs diff  filled jobs % diff  \
# 0        93195                93706               511                 0.5
# 1         5340                 5355                15                 0.3
# 2       217139               218967              1828                 0.8
# 3        19886                20060               174                 0.9
# 4       166413               168095              1682                 1.0
#
# ...

# %% [markdown]
# Pivot Table

# %%
pd.pivot_table(data,'filled jobs','filled jobs diff',aggfunc=np.mean)
# Out:
#                   filled jobs
# filled jobs diff
# -161                  68878.0
# -9                     5393.0
# -5                     5553.0
# -3                   151314.0
#  0                     5354.0
# ...                       ...
#  20939              2116740.0
#  21227              2187716.0
#  22139              2141825.0
#  22615              2233837.0
#  28071              2129855.0
#
# [197 rows x 1 columns]

# %%
pd.pivot_table(data,'filled jobs','filled jobs revised','filled jobs diff',aggfunc=np.mean)
# Out:
# filled jobs diff     -161    -9      -5      -3       0       2       3      \
# filled jobs revised
# 5295                    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5353                    NaN     NaN     NaN     NaN     NaN  5351.0     NaN
# 5354                    NaN     NaN     NaN     NaN  5354.0     NaN     NaN
# 5355                    NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5384                    NaN  5393.0     NaN     NaN     NaN     NaN     NaN
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2196169                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2208943                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2209339                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2215805                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2256452                 NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
# ...

# %%
pd.pivot_table(data,'filled jobs','filled jobs revised','filled jobs diff',aggfunc=np.mean,margins=True)
# Out:
# filled jobs diff        -161      -9      -5        -3       0       2  \
# filled jobs revised
# 5295                     NaN     NaN     NaN       NaN     NaN     NaN
# 5353                     NaN     NaN     NaN       NaN     NaN  5351.0
# 5354                     NaN     NaN     NaN       NaN  5354.0     NaN
# 5355                     NaN     NaN     NaN       NaN     NaN     NaN
# 5384                     NaN  5393.0     NaN       NaN     NaN     NaN
# ...                      ...     ...     ...       ...     ...     ...
# 2208943                  NaN     NaN     NaN       NaN     NaN     NaN
# 2209339                  NaN     NaN     NaN       NaN     NaN     NaN
# 2215805                  NaN     NaN     NaN       NaN     NaN     NaN
# 2256452                  NaN     NaN     NaN       NaN     NaN     NaN
# All                  68878.0  5393.0  5553.0  151314.0  5354.0  5351.0
#
# filled jobs diff          3      15      19      24  ...      17496  \
# ...

# %%
pd.pivot_table(data,'filled jobs',['filled jobs revised','filled jobs diff'],'total_earnings',aggfunc=np.mean,margins=True,margins_name="overall_Average")
# Out:
# total_earnings                           140     142     145     150     153  \
# filled jobs revised filled jobs diff
# 5295                24                5271.0     NaN     NaN     NaN     NaN
# 5353                2                    NaN     NaN  5351.0     NaN     NaN
# 5354                0                    NaN  5354.0     NaN     NaN     NaN
# 5355                15                   NaN     NaN  5340.0     NaN     NaN
# 5384                -9                   NaN     NaN     NaN     NaN  5393.0
# ...                                      ...     ...     ...     ...     ...
# 2208943             21227                NaN     NaN     NaN     NaN     NaN
# 2209339             19744                NaN     NaN     NaN     NaN     NaN
# 2215805             18831                NaN     NaN     NaN     NaN     NaN
# 2256452             22615                NaN     NaN     NaN     NaN     NaN
# overall_Average                       5271.0  5354.0  5345.5  5400.0  5393.0
#
# ...

# %%
pd.pivot_table(data,'filled jobs','total_earnings',['filled jobs revised','filled jobs diff'],aggfunc=np.mean,margins=True,margins_name="overall_Average")
# Out:
# filled jobs revised    5295    5353    5354    5355    5384    5410    5427  \
# filled jobs diff         24       2       0      15      -9       3      27
# total_earnings
# 140                  5271.0     NaN     NaN     NaN     NaN     NaN     NaN
# 142                     NaN     NaN  5354.0     NaN     NaN     NaN     NaN
# 145                     NaN  5351.0     NaN  5340.0     NaN     NaN     NaN
# 150                     NaN     NaN     NaN     NaN     NaN     NaN  5400.0
# 153                     NaN     NaN     NaN     NaN  5393.0     NaN     NaN
# ...                     ...     ...     ...     ...     ...     ...     ...
# 37856                   NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 38353                   NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 39160                   NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 40646                   NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...
